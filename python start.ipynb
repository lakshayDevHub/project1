# %%
print("hello how are you")  #-----string
print('hello how are you')  #--string 

print(46)  #----integer
print(4.4)  #--float

print(True)
print(False) #----boolean
# Out:
# hello
# hello
# 46
# 4.4

# %% [markdown]
# Type fuction

# %%
print("6.8")
print(type("6'8"))
# Out:
# 6.8
# <class 'str'>

# %% [markdown]
# variables----

# %%
x= "hello how are you "
print(x.upper())
print(x.lower())
print(x.title())
print(x.capitalize())
# Out:
# HELLO HOW ARE YOU
# hello how are you
# Hello How Are You
# Hello how are you

# %%
x= "hello how are you "
print(x.isupper())
print(x.islower())
print(x.isalpha())
print(x.isalnum())
print(x.isdigit())
# Out:
# False
# True
# False
# False
# False

# %%
x= int (input("enter a 1st num"))
y= int(input("enter a 2nd num"))
z=x+y
print(z)
# Out:
# enter a 1st num 34
# enter a 2nd num 56
# 90

# %% [markdown]
# opreators #-----eg *,+,-,/--(float)--> 2.5
# relational opr #---->humesha true or false vale dega
# > ----->greater then
# == ---->equal
# != ----->not equal
# >= ----->greater then equalto
# <= ----->less then equal to

# %%
x="hello how are you"
print(x.replace("h","hi",1))
# Out:
# hiello how are you

# %%
x=10
y=20
print(x)
print(y)
# Out:
# 10
# 20

# %%
x=10
y=10
print(x==y)
print(x is y)
# Out:
# True
# True
